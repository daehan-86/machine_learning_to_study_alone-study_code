# %% [markdown]
# # **텍스트셀 사용법**
#
# * # 제목1 - < h1 >태그와 동일
# * ## 제목2 - < h2 >태그와 동일
# * **내용** - 굵은 글씨 (또는__)
# * *내용* - 기울인 글씨 (또는_)
# * ~~내용~~ - 취소선 글씨
# * <u>내용</u> - 밑줄친 글씨
# * `코드` - 코드 서체
# * > 내용 - 들여쓰기
# * * 내용 - 글머리 기호
# * [구글](https://www.google.com/) - 링크만들기
# * ![구글](https://www.google.com/logos/doodles/2022/seasonal-holidays-2022-6753651837109831.2-law.gif) - 사진 넣기
# * $ y = x \times z$ - 수학식 넣기
